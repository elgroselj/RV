# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv


import sys
sys.path.append(".")
from ex2_utils import generate_responses_1, generate_responses_2, create_epanechnik_kernel, get_patch, extract_histogram, backproject_histogram
from run_ms_tracker import run_ms_tracker_fun


r = []
    # for sequence in ['basketball', 'bicycle', 'drunk', 'sphere', 'surfing']:
for sequence in ['drunk']:
    n_failures = run_ms_tracker_fun(sequence)
    r.append((sequence, n_failures))
print(r)

# [('basketball', 3), ('bicycle', 0), ('drunk', 19)(proti koncu polovica failov), ('sphere', 2), ('surfing', 5)]
# Out:
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  6
# Break: meanshift is zero n_iter:  10
# Break: meanshift is zero n_iter:  17
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  9
# Break: meanshift is zero n_iter:  5
# Break: meanshift is zero n_iter:  5
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  0
# Break: meanshift is zero n_iter:  5
# ...
